# %%
import pandas as pd
import os

# import data
data_df = pd.read_csv('./data.csv')
# Out:
#    Date / Time  host#HOST1#% Free Memory avg 1 h  \
# 0   1319169600                             77.89
# 1   1319173200                             77.89
#
#    host#HOST2#% Free Memory avg 1 h  host#HOST3#% Free Memory avg 1 h  \
# 0                             77.73                             77.79
# 1                             77.73                             77.79
#
#    host#HOST4#% Free Memory avg 1 h  host#HOST5#% Free Memory avg 1 h  \
# 0                             78.06                             87.26
# 1                             78.06                             87.47
#
#    host#HOST6#% Free Memory avg 1 h  host#HOST7#% Free Memory avg 1 h  \
# 0                             93.41                             96.65
# 1                             93.44                             96.64
#
#    host#HOST8#% Free Memory avg 1 h  host#HOST9#% Free Memory avg 1 h  ...  \
# 0                             90.66                             96.40  ...
# 1                             90.71                             96.41  ...
#
#    host#HOST20#% Free Memory avg 1 h  host#HOST21#% Free Memory avg 1 h  \
# 0                              72.13                              54.72
# 1                              71.95                              56.12
#
#    host#HOST22#% Free Memory avg 1 h  host#HOST23#% Free Memory avg 1 h  \
# 0                              57.55                              36.66
# 1                              61.31                              37.83
#
#    host#HOST24#% Free Memory avg 1 h  host#HOST25#% Free Memory avg 1 h  \
# 0                              33.90                              35.55
# 1                              39.13                              33.12
#
#    host#HOST26#% Free Memory avg 1 h  host#HOST27#% Free Memory avg 1 h  \
# 0                              44.61                              44.99
# 1                              46.13                              45.93
#
#    host#HOST28#% Free Memory avg 1 h  host#HOST29#% Free Memory avg 1 h
# 0                              45.59                              40.13
# 1                              47.57                              32.24
#
# [2 rows x 30 columns]

# %%
# generate the min, max, and avrage for each host and an aggrage for all hosts
data_df_no_dt = data_df.drop(['Date / Time'], axis=1)
mins = data_df_no_dt.min()
all_min = mins.min()
maxs = data_df_no_dt.max()
all_max = mins.max()
means = data_df_no_dt.mean()
all_mean = mins.mean()

# %%
# produce a pandas dataframe
columns = ["descriptions", "all"] + list(data_df_no_dt.columns)
data = [
    ["min", all_min] + list(mins),
    ["max", all_max] + list(maxs),
    ["mean", all_mean] + list(means)
]

output_df = pd.DataFrame(data, columns=columns)
output_df = output_df.set_index("descriptions")

# %%
# print stdout of output
print(output_df.to_string())
# Out:
#                     all  host#HOST1#% Free Memory avg 1 h  host#HOST2#% Free Memory avg 1 h  host#HOST3#% Free Memory avg 1 h  host#HOST4#% Free Memory avg 1 h  host#HOST5#% Free Memory avg 1 h  host#HOST6#% Free Memory avg 1 h  host#HOST7#% Free Memory avg 1 h  host#HOST8#% Free Memory avg 1 h  host#HOST9#% Free Memory avg 1 h  host#HOST10#% Free Memory avg 1 h  host#HOST11#% Free Memory avg 1 h  host#HOST12#% Free Memory avg 1 h  host#HOST13#% Free Memory avg 1 h  host#HOST14#% Free Memory avg 1 h  host#HOST15#% Free Memory avg 1 h  host#HOST16#% Free Memory avg 1 h  host#HOST17#% Free Memory avg 1 h  host#HOST18#% Free Memory avg 1 h  host#HOST19#% Free Memory avg 1 h  host#HOST20#% Free Memory avg 1 h  host#HOST21#% Free Memory avg 1 h  host#HOST22#% Free Memory avg 1 h  host#HOST23#% Free Memory avg 1 h  host#HOST24#% Free Memory avg 1 h  host#HOST25#% Free Memory avg 1 h  host#HOST26#% Free Memory avg 1 h  host#HOST27#% Free Memory avg 1 h  host#HOST28#% Free Memory avg 1 h  host#HOST29#% Free Memory avg 1 h
# descriptions
# min           31.820000                           77.8500                         77.690000                         77.750000                            78.030                           85.9200                            93.280                         96.500000                         90.070000                          96.10000                             99.230                           94.84000                           54.27000                          39.540000                          51.160000                           81.26000                            85.0900                          60.580000                          79.350000                          82.420000                          71.120000                          54.340000                          57.550000                          35.760000                              33.64                           32.32000                           41.43000                           43.53000                          43.230000                          31.820000
# max           99.230000                           77.8900                         77.730000                         77.790000                            78.060                           87.4700                            93.640                         96.830000                         92.090000                          96.52000                             99.570                           94.98000                           54.84000                          40.800000                          51.380000                           81.30000                            93.4600                          61.200000                          97.420000                          83.140000                          73.030000                          61.110000                          61.310000                          41.910000                              40.69                           45.79000                           46.13000                           47.21000                          49.010000                          41.610000
# mean          67.092069                           77.8625                         77.708333                         77.774167                            78.045                           86.8425                            93.495                         96.682917                         90.807917                          96.34913                             99.404                           94.90125                           54.76625                          40.522917                          51.274167                           81.28875                            92.1025                          61.169583                          82.982917                          82.770833                          71.924167                          57.691667                          59.982917                          37.352083                              36.76                           36.95625                           43.36375                           45.06625                          45.638333                          36.365455

# %%
# format output for json
output_df_json = output_df.reset_index()
output_df_json = output_df_json.to_dict()
def mapped_dict(d):
    return {"min": d[0], "max": d[1], "mean": d[2]}
output_df_json = { k: mapped_dict(output_df_json[k]) for k, v in output_df_json.items()}
output_df_json.pop("descriptions")
output_df_json
# Out:
# {'all': {'min': 31.82, 'max': 99.23, 'mean': 67.09206896551723},
#  'host#HOST1#% Free Memory avg 1 h': {'min': 77.85,
#   'max': 77.89,
#   'mean': 77.86249999999997},
#  'host#HOST2#% Free Memory avg 1 h': {'min': 77.69,
#   'max': 77.73,
#   'mean': 77.70833333333336},
#  'host#HOST3#% Free Memory avg 1 h': {'min': 77.75,
#   'max': 77.79,
#   'mean': 77.77416666666666},
#  'host#HOST4#% Free Memory avg 1 h': {'min': 78.03,
#   'max': 78.06,
#   'mean': 78.04499999999997},
#  'host#HOST5#% Free Memory avg 1 h': {'min': 85.92,
#   'max': 87.47,
#   'mean': 86.84249999999999},
#  'host#HOST6#% Free Memory avg 1 h': {'min': 93.28,
#   'max': 93.64,
#   'mean': 93.49499999999999},
#  'host#HOST7#% Free Memory avg 1 h': {'min': 96.5,
#   'max': 96.83,
#   'mean': 96.68291666666669},
#  'host#HOST8#% Free Memory avg 1 h': {'min': 90.07,
#   'max': 92.09,
#   'mean': 90.80791666666669},
#  'host#HOST9#% Free Memory avg 1 h': {'min': 96.1,
#   'max': 96.52,
#   'mean': 96.3491304347826},
#  'host#HOST10#% Free Memory avg 1 h': {'min': 99.23,
#   'max': 99.57,
#   'mean': 99.40400000000001},
#  'host#HOST11#% Free Memory avg 1 h': {'min': 94.84,
#   'max': 94.98,
#   'mean': 94.90125},
#  'host#HOST12#% Free Memory avg 1 h': {'min': 54.27,
#   'max': 54.84,
#   'mean': 54.76625000000001},
#  'host#HOST13#% Free Memory avg 1 h': {'min': 39.54,
#   'max': 40.8,
#   'mean': 40.522916666666674},
#  'host#HOST14#% Free Memory avg 1 h': {'min': 51.16,
#   'max': 51.38,
#   'mean': 51.27416666666668},
#  'host#HOST15#% Free Memory avg 1 h': {'min': 81.26,
#   'max': 81.3,
#   'mean': 81.28874999999998},
#  'host#HOST16#% Free Memory avg 1 h': {'min': 85.09,
#   'max': 93.46,
#   'mean': 92.10249999999996},
#  'host#HOST17#% Free Memory avg 1 h': {'min': 60.58,
#   'max': 61.2,
#   'mean': 61.16958333333336},
#  'host#HOST18#% Free Memory avg 1 h': {'min': 79.35,
#   'max': 97.42,
#   'mean': 82.98291666666667},
#  'host#HOST19#% Free Memory avg 1 h': {'min': 82.42,
#   'max': 83.14,
#   'mean': 82.77083333333333},
#  'host#HOST20#% Free Memory avg 1 h': {'min': 71.12,
#   'max': 73.03,
#   'mean': 71.92416666666668},
#  'host#HOST21#% Free Memory avg 1 h': {'min': 54.34,
#   'max': 61.11,
#   'mean': 57.69166666666667},
#  'host#HOST22#% Free Memory avg 1 h': {'min': 57.55,
#   'max': 61.31,
#   'mean': 59.982916666666654},
#  'host#HOST23#% Free Memory avg 1 h': {'min': 35.76,
#   'max': 41.91,
#   'mean': 37.35208333333333},
#  'host#HOST24#% Free Memory avg 1 h': {'min': 33.64,
#   'max': 40.69,
#   'mean': 36.76},
#  'host#HOST25#% Free Memory avg 1 h': {'min': 32.32,
#   'max': 45.79,
#   'mean': 36.956250000000004},
#  'host#HOST26#% Free Memory avg 1 h': {'min': 41.43,
#   'max': 46.13,
#   'mean': 43.36375},
#  'host#HOST27#% Free Memory avg 1 h': {'min': 43.53,
#   'max': 47.21,
#   'mean': 45.06625},
#  'host#HOST28#% Free Memory avg 1 h': {'min': 43.23,
#   'max': 49.01,
#   'mean': 45.63833333333333},
#  'host#HOST29#% Free Memory avg 1 h': {'min': 31.82,
#   'max': 41.61,
#   'mean': 36.36545454545455}}

# %%
# save output as csv and json under outputs directory
if not os.path.exists('./outputs'):
    os.makedirs('./outputs')

output_df.to_csv('./outputs/output.csv')
output_df.to_json('./outputs/output.json')
